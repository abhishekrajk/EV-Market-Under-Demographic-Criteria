# %% [markdown]
# """"!pip install opencv-python
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
dataset = pd.read_csv(r"C:\Users\admin2\Downloads\Final Dataset-EV.csv")

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head(10))
# Out:
# Index(['Unnamed: 0', 'Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PlugType',
#        'BodyStyle', 'Segment', 'Seats', 'PriceRupees'],
#       dtype='object')
# (103, 14)
#    Unnamed: 0        Brand                          Model  AccelSec  \
# 0           0       Tesla   Model 3 Long Range Dual Motor         5
# 1           1  Volkswagen                       ID.3 Pure        10
# 2           2    Polestar                               2         5
# 3           3         BMW                            iX3          7
# 4           4       Honda                              e         10
# 5           5       Lucid                            Air          3
# 6           6  Volkswagen                         e-Golf         10
# 7           7     Peugeot                          e-208          8
# 8           8       Tesla     Model 3 Standard Range Plus         6
# 9           9        Audi                      Q4 e-tron          6
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
# 2           210       400              181             620         Yes
# 3           180       360              206             560         Yes
# 4           145       170              168             190         Yes
# 5           250       610              180             620         Yes
# 6           150       190              168             220          No
# 7           150       275              164             420          No
# 8           225       310              153             650         Yes
# 9           180       400              193             540         Yes
#
#      PlugType  BodyStyle Segment  Seats  PriceRupees
# 0  Type 2 CCS      Sedan       D      5   5024879.08
# 1  Type 2 CCS  Hatchback       C      5   2717130.00
# 2  Type 2 CCS   Liftback       D      5   5111827.24
# 3  Type 2 CCS        SUV       D      5   6162450.84
# 4  Type 2 CCS  Hatchback       B      4   2988571.29
# 5  Type 2 CCS      Sedan       F      5   9509955.00
# 6  Type 2 CCS  Hatchback       C      5   2889214.90
# 7  Type 2 CCS  Hatchback       B      5   2688328.42
# 8  Type 2 CCS      Sedan       D      5   4200682.98
# 9  Type 2 CCS        SUV       D      5   4981405.00

# %%
dataset.head(5)
# Out:
#    Unnamed: 0        Brand                          Model  AccelSec  \
# 0           0       Tesla   Model 3 Long Range Dual Motor         5
# 1           1  Volkswagen                       ID.3 Pure        10
# 2           2    Polestar                               2         5
# 3           3         BMW                            iX3          7
# 4           4       Honda                              e         10
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
# 2           210       400              181             620         Yes
# 3           180       360              206             560         Yes
# 4           145       170              168             190         Yes
#
#      PlugType  BodyStyle Segment  Seats  PriceRupees
# 0  Type 2 CCS      Sedan       D      5   5024879.08
# 1  Type 2 CCS  Hatchback       C      5   2717130.00
# 2  Type 2 CCS   Liftback       D      5   5111827.24
# 3  Type 2 CCS        SUV       D      5   6162450.84
# 4  Type 2 CCS  Hatchback       B      4   2988571.29

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PlugType',
#        'BodyStyle', 'Segment', 'Seats', 'PriceRupees'],
#       dtype='object')

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Iterate through each column and apply label encoding
for column in dataset.columns:
    if dataset[column].dtype == 'object':  # Check if the column contains categorical data
        dataset[column] = label_encoder.fit_transform(dataset[column])

# %%
dataset
# Out:
#      Unnamed: 0  Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 0             0     30     46         5           233       450
# 1             1     31     33        10           160       270
# 2             2     23      0         5           210       400
# 3             3      2    101         7           180       360
# 4             4      9     78        10           145       170
# ..          ...    ...    ...       ...           ...       ...
# 98           98     20      6         8           160       330
# 99           99      1     94         5           210       335
# 100         100     20      8         6           200       325
# 101         101     20     10         5           200       375
# 102         102      3     42         8           190       400
#
#      Efficiency_WhKm  FastCharge_KmH  RapidCharge  PlugType  BodyStyle  \
# 0                161             940            1         2          7
# 1                167             250            0         2          1
# 2                181             620            1         2          2
# 3                206             560            1         2          6
# 4                168             190            1         2          1
# ..               ...             ...          ...       ...        ...
# 98               191             440            1         2          1
# 99               258             540            1         2          6
# 100              194             440            1         2          1
# 101              232             450            1         2          1
# 102              238             480            0         2          6
#
#      Segment  Seats  PriceRupees
# 0          3      5   5024879.08
# 1          2      5   2717130.00
# 2          3      5   5111827.24
# 3          3      5   6162450.84
# 4          1      4   2988571.29
# ..       ...    ...          ...
# 98         2      5   4075695.00
# 99         4      5   8699344.55
# 100        2      5   4528550.00
# 101        2      5   5887115.00
# 102        4      5   5615402.00
#
# [103 rows x 14 columns]

# %%
if __name__ == "__main__":
    dataset = np.array([
         'AccelSec', 'TopSpeed_KmH', 'Range_Km',
       'Efficiency_WhKm', 'FastCharge_KmH','PriceRupees'
    ])

# %%
n_clusters =3

# %%
def perform_kmeans_clustering(dataset, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(dataset)
    cluster_centers = kmeans.cluster_centers_
    return labels, cluster_centers

# %%
labels, cluster_centers = perform_kmeans_clustering(dataset, n_clusters)

print("Cluster Labels:", labels)
print("Cluster Centers:", cluster_centers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 labels, cluster_centers = perform_kmeans_clustering(dataset, n_clusters)
#       3 print("Cluster Labels:", labels)
#       4 print("Cluster Centers:", cluster_centers)
#
# Input In [21], in perform_kmeans_clustering(dataset, n_clusters)
#       1 def perform_kmeans_clustering(dataset, n_clusters):
#       2     kmeans = KMeans(n_clusters=n_clusters, random_state=0)
# ----> 3     labels = kmeans.fit_predict(dataset)
#       4     cluster_centers = kmeans.cluster_centers_
#       5     return labels, cluster_centers
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:1033, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1010 def fit_predict(self, X, y=None, sample_weight=None):
#    1011     """Compute cluster centers and predict cluster index for each sample.
#    1012
#    1013     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1031         Index of the cluster each sample belongs to.
#    1032     """
# -> 1033     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
#    1426 self._check_params_vs_input(X)
#    1428 random_state = check_random_state(self.random_state)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:535, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     533     raise ValueError("Validation should be done on X, y or both.")
#     534 elif not no_val_X and no_val_y:
# --> 535     X = check_array(X, input_name="X", **check_params)
#     536     out = X
#     537 elif no_val_X and not no_val_y:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:877, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     875         array = xp.astype(array, dtype, copy=False)
#     876     else:
# --> 877         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     878 except ComplexWarning as complex_warning:
#     879     raise ValueError(
#     880         "Complex data not supported\n{}\n".format(array)
#     881     ) from complex_warning
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# ValueError: could not convert string to float: 'AccelSec'
